# %% [markdown]
# # Pianofy Backend API Server 🎹
# Rode esta célula para iniciar o backend do Pianofy gratuitamente usando a GPU do Google Colab!

# %%
# !git clone https://github.com/Tempestugo/pianofy.git
# %cd pianofy/backend
# !apt-get update
# !apt-get install -y ffmpeg libsndfile1
# !pip install -r requirements.txt
# !npm install -g localtunnel

import urllib.request
print("=========================================")
print("A SENHA DO SEU TUNEL É:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())
print("=========================================")

# !uvicorn main:app --port 8000 & lt --port 8000
